# %%
# Run for depedency
# just run the notbeook :)

# %%
pip install pandas numpy scipy dask matplotlib seaborn plotly scikit-learn openpyxl
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting numpy
#   Downloading numpy-2.1.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (62 kB)
# Collecting scipy
#   Downloading scipy-1.14.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting dask
#   Downloading dask-2024.11.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting plotly
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting click>=8.1 (from dask)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle>=3.0.0 (from dask)
#   Downloading cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting fsspec>=2021.09.0 (from dask)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from dask) (24.2)
# Collecting partd>=1.4.0 (from dask)
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from dask) (6.0.2)
# Collecting toolz>=0.10.0 (from dask)
#   Downloading toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (164 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting locket (from partd>=1.4.0->dask)
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 6.4 MB/s eta 0:00:006.3 MB/s eta 0:00:01
# Downloading numpy-2.1.3-cp312-cp312-macosx_11_0_arm64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 5.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading scipy-1.14.1-cp312-cp312-macosx_12_0_arm64.whl (29.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.9/29.9 MB 5.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading dask-2024.11.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading matplotlib-3.9.2-cp312-cp312-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 5.0 MB/s eta 0:00:005.1 MB/s eta 0:00:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 6.0 MB/s eta 0:00:005.9 MB/s eta 0:00:01
# Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 7.5 MB/s eta 0:00:007.8 MB/s eta 0:00:01
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Downloading contourpy-1.3.1-cp312-cp312-macosx_11_0_arm64.whl (255 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.0-cp312-cp312-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.8 MB/s eta 0:00:004.5 MB/s eta 0:00:01
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading kiwisolver-1.4.7-cp312-cp312-macosx_11_0_arm64.whl (63 kB)
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading pillow-11.0.0-cp312-cp312-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 5.7 MB/s eta 0:00:005.8 MB/s eta 0:00:01
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: pytz, tzdata, toolz, threadpoolctl, tenacity, pyparsing, pillow, numpy, locket, kiwisolver, joblib, fsspec, fonttools, et-xmlfile, cycler, cloudpickle, click, scipy, plotly, partd, pandas, openpyxl, contourpy, scikit-learn, matplotlib, dask, seaborn
# Successfully installed click-8.1.7 cloudpickle-3.1.0 contourpy-1.3.1 cycler-0.12.1 dask-2024.11.2 et-xmlfile-2.0.0 fonttools-4.55.0 fsspec-2024.10.0 joblib-1.4.2 kiwisolver-1.4.7 locket-1.0.0 matplotlib-3.9.2 numpy-2.1.3 openpyxl-3.1.5 pandas-2.2.3 partd-1.4.2 pillow-11.0.0 plotly-5.24.1 pyparsing-3.2.0 pytz-2024.2 scikit-learn-1.5.2 scipy-1.14.1 seaborn-0.13.2 tenacity-9.0.0 threadpoolctl-3.5.0 toolz-1.0.0 tzdata-2024.2
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fgclustering
# Out:
# Collecting fgclustering
#   Downloading fgclustering-1.1.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from fgclustering) (2.2.3)
# Requirement already satisfied: numpy in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from fgclustering) (2.1.3)
# Requirement already satisfied: matplotlib in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from fgclustering) (3.9.2)
# Requirement already satisfied: seaborn>=0.12 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from fgclustering) (0.13.2)
# Requirement already satisfied: scikit-learn in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from fgclustering) (1.5.2)
# Collecting kmedoids (from fgclustering)
#   Downloading kmedoids-0.5.2-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (9.6 kB)
# Requirement already satisfied: scipy in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from fgclustering) (1.14.1)
# Collecting tqdm (from fgclustering)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting statsmodels>=0.13.5 (from fgclustering)
#   Downloading statsmodels-0.14.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting numexpr>=2.8.4 (from fgclustering)
#   Downloading numexpr-2.10.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting numba (from fgclustering)
#   Downloading numba-0.60.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: plotly in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from fgclustering) (5.24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from matplotlib->fgclustering) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from matplotlib->fgclustering) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from matplotlib->fgclustering) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from matplotlib->fgclustering) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from matplotlib->fgclustering) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from matplotlib->fgclustering) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from matplotlib->fgclustering) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from matplotlib->fgclustering) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas->fgclustering) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas->fgclustering) (2024.2)
# Collecting patsy>=0.5.6 (from statsmodels>=0.13.5->fgclustering)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba->fgclustering)
#   Downloading llvmlite-0.43.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting numpy (from fgclustering)
#   Downloading numpy-2.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (114 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from plotly->fgclustering) (9.0.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from scikit-learn->fgclustering) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from scikit-learn->fgclustering) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->fgclustering) (1.16.0)
# Downloading fgclustering-1.1.1-py3-none-any.whl (23 kB)
# Downloading numexpr-2.10.2-cp312-cp312-macosx_11_0_arm64.whl (134 kB)
# Downloading statsmodels-0.14.4-cp312-cp312-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 2.5 MB/s eta 0:00:000:00:010:00:01:01
# Downloading kmedoids-0.5.2-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (911 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.1/911.1 kB 3.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading numba-0.60.0-cp312-cp312-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 3.4 MB/s eta 0:00:003.5 MB/s eta 0:00:01
# Downloading numpy-2.0.2-cp312-cp312-macosx_11_0_arm64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 3.0 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading llvmlite-0.43.0-cp312-cp312-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: kmedoids, tqdm, numpy, llvmlite, patsy, numexpr, numba, statsmodels, fgclustering
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# Successfully installed fgclustering-1.1.1 kmedoids-0.5.2 llvmlite-0.43.0 numba-0.60.0 numexpr-2.10.2 numpy-2.0.2 patsy-1.0.1 statsmodels-0.14.4 tqdm-4.67.1
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install palmerpenguins
# Out:
# Collecting palmerpenguins
#   Downloading palmerpenguins-0.1.4-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from palmerpenguins) (2.2.3)
# Requirement already satisfied: numpy in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from palmerpenguins) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas->palmerpenguins) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas->palmerpenguins) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas->palmerpenguins) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->palmerpenguins) (1.16.0)
# Downloading palmerpenguins-0.1.4-py3-none-any.whl (17 kB)
# Installing collected packages: palmerpenguins
# Successfully installed palmerpenguins-0.1.4
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
## Import the Forest-Guided Clustering package
from fgclustering import FgClustering

## Imports for datasets
from palmerpenguins import load_penguins
from sklearn.datasets import load_breast_cancer, fetch_california_housing

## Additional imports for use-cases
import joblib
import pandas as pd

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
data_breast_cancer = load_breast_cancer(as_frame=True)
data_breast_cancer = data_breast_cancer.frame
data_breast_cancer['target'] = data_breast_cancer['target'].map({0: 'malignant', 1: 'benign'})
data_breast_cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension     target
# 0          0.4601                  0.11890  malignant
# 1          0.2750                  0.08902  malignant
# 2          0.3613                  0.08758  malignant
# 3          0.6638                  0.17300  malignant
# 4          0.2364                  0.07678  malignant
#
# [5 rows x 31 columns]

# %%
X_breast_cancer = data_breast_cancer.loc[:, data_breast_cancer.columns != 'target']
y_breast_cancer = data_breast_cancer.target

classifier = RandomForestClassifier(max_samples=0.8, bootstrap=True, oob_score=True, random_state=42)

grid = {'max_depth':[2, 5], 'max_features': ['sqrt', 'log2']}
grid_classifier = GridSearchCV(classifier, grid, cv=5)
grid_classifier.fit(X_breast_cancer, y_breast_cancer)
rf_breast_cancer = grid_classifier.best_estimator_

print(f'Parameters of best prediction model: {grid_classifier.best_params_}')
print(f'OOB accuracy of prediction model: {round(rf_breast_cancer.oob_score_,3)}')
# Out:
# Parameters of best prediction model: {'max_depth': 5, 'max_features': 'sqrt'}
# OOB accuracy of prediction model: 0.954

# %%
fgc = FgClustering(model=rf_breast_cancer, data=data_breast_cancer, target_column='target')
# Out:
# Interpreting RandomForestClassifier

# %%
fgc.run()
# Out:
#  17%|████████████████████████████                                                                                                                                            | 1/6 [00:01<00:05,  1.03s/it]
# For number of cluster 2 the Jaccard Index is 0.9977762891115787
# For number of cluster 2 the score is 0.06613635989234057
#  33%|████████████████████████████████████████████████████████                                                                                                                | 2/6 [00:01<00:03,  1.24it/s]
# For number of cluster 3 the Jaccard Index is 0.8861827734206449
# For number of cluster 3 the score is 0.07478999977783318
#  50%|████████████████████████████████████████████████████████████████████████████████████                                                                                    | 3/6 [00:02<00:02,  1.12it/s]
# For number of cluster 4 the Jaccard Index is 0.5036478848646798
# Clustering is instable, no score computed!
#  67%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                        | 4/6 [00:04<00:02,  1.10s/it]
# For number of cluster 5 the Jaccard Index is 0.5934978039560798
# Clustering is instable, no score computed!
#  83%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                            | 5/6 [00:06<00:01,  1.40s/it]
# For number of cluster 6 the Jaccard Index is 0.33292910886203164
# Clustering is instable, no score computed!
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:08<00:00,  1.42s/it]
# For number of cluster 7 the Jaccard Index is 0.43566831779331777
# Clustering is instable, no score computed!
# Optimal number of cluster is: 2

# %%
fgc.plot_decision_paths(thr_pvalue=1, num_cols = 7)

# %%
fgc
type(fgc)
# Out:
# fgclustering.forest_guided_clustering.FgClustering

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.1_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
